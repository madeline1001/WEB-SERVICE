# %%
import requests

# %%
# Definir endpoint
url = 'http://127.0.0.1:8000/upload-excel'

# Definir path del Excel
file_path = "prueba.xlsx"
files = {"file": open(file_path, "rb")}

# Hacer la solicitud POST
response = requests.post(url=url, files=files)

# Verificar el código de estado y la respuesta
print(response.status_code)
if response.status_code == 200:
    print(response.json())
else:
    print("Error en la solicitud:", response.text)
# Out:
# 200
# {'predictions': [634.6373620073741, 436.51504902609906, 434.0813618043362, 559.3904521478123, 576.7804566637046, 544.9225857935025, 509.45622389076186, 490.932067345631, 532.3748987180326, 467.41368193818914, 471.1912628594665, 373.99114577047123, 468.9715460029919, 438.38853713176115, 432.4116907375652, 494.72209272451653, 466.10744215507725, 540.2602142446806, 506.656157976925, 616.8916391849582, 473.2679887514264, 364.5464461341576, 449.95774839186197, 357.0478443705165, 375.45453218732246, 535.301790577703, 481.3275045891728, 495.4022996345052, 483.21552347562204, 505.1884844628935, 551.3038490288384, 450.9146666832652, 514.6330704877973, 492.04511394281576, 400.5901573071586, 478.9965670699113, 460.10245135550565, 431.12303327338566, 534.8026237143223, 465.7212356598536, 571.007745692966, 439.4715195020352, 590.256564437386, 633.8551487301909, 360.18429299055845, 450.6696212632796, 409.11219050060856, 483.53058644962005, 680.0372717340736, 384.8145512318423, 495.2682709627063, 453.94848080815507, 626.1361896925696, 633.9254104115996, 567.8630354259212, 364.5900810268796, 623.4103852550415, 601.5679617071335, 491.0547875347777, 495.6862682714702, 309.0742908294353, 451.7482610053685, 334.53317854190664, 477.568613740674, 641.9175446571685, 495.97770999908664, 597.5508022729243, 415.48783017807204, 482.8249099988042, 459.782538314508, 363.49933351560935, 496.9831084732849, 580.3589703633149, 559.7863509788501, 530.2457085696889]}
